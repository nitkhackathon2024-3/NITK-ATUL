# %%
import numpy as np
import pandas as pd

# %%
Data = pd.read_csv('creditcard.csv')
Data.head(5)
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
#         V26       V27       V28  Amount  Class
# 0 -0.189115  0.133558 -0.021053  149.62      0
# 1  0.125895 -0.008983  0.014724    2.69      0
# 2 -0.139097 -0.055353 -0.059752  378.66      0
# 3 -0.221929  0.062723  0.061458  123.50      0
# 4  0.502292  0.219422  0.215153   69.99      0
#
# [5 rows x 31 columns]

# %%
Data.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  1.168375e-15  3.416908e-16 -1.379537e-15  2.074095e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   9.604066e-16  1.487313e-15 -5.556467e-16  1.213481e-16 -2.406331e-15
# std    1.380247e+00  1.332271e+00  1.237094e+00  1.194353e+00  1.098632e+00
# min   -1.137433e+02 -2.616051e+01 -4.355724e+01 -7.321672e+01 -1.343407e+01
# 25%   -6.915971e-01 -7.682956e-01 -5.540759e-01 -2.086297e-01 -6.430976e-01
# 50%   -5.433583e-02 -2.741871e-01  4.010308e-02  2.235804e-02 -5.142873e-02
# 75%    6.119264e-01  3.985649e-01  5.704361e-01  3.273459e-01  5.971390e-01
# max    3.480167e+01  7.330163e+01  1.205895e+02  2.000721e+01  1.559499e+01
#
#        ...           V21           V22           V23           V24  \
# count  ...  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   ...  1.654067e-16 -3.568593e-16  2.578648e-16  4.473266e-15
# std    ...  7.345240e-01  7.257016e-01  6.244603e-01  6.056471e-01
# min    ... -3.483038e+01 -1.093314e+01 -4.480774e+01 -2.836627e+00
# 25%    ... -2.283949e-01 -5.423504e-01 -1.618463e-01 -3.545861e-01
# 50%    ... -2.945017e-02  6.781943e-03 -1.119293e-02  4.097606e-02
# 75%    ...  1.863772e-01  5.285536e-01  1.476421e-01  4.395266e-01
# max    ...  2.720284e+01  1.050309e+01  2.252841e+01  4.584549e+00
#
#                 V25           V26           V27           V28         Amount  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  284807.000000
# mean   5.340915e-16  1.683437e-15 -3.660091e-16 -1.227390e-16      88.349619
# std    5.212781e-01  4.822270e-01  4.036325e-01  3.300833e-01     250.120109
# min   -1.029540e+01 -2.604551e+00 -2.256568e+01 -1.543008e+01       0.000000
# 25%   -3.171451e-01 -3.269839e-01 -7.083953e-02 -5.295979e-02       5.600000
# 50%    1.659350e-02 -5.213911e-02  1.342146e-03  1.124383e-02      22.000000
# 75%    3.507156e-01  2.409522e-01  9.104512e-02  7.827995e-02      77.165000
# max    7.519589e+00  3.517346e+00  3.161220e+01  3.384781e+01   25691.160000
#
#                Class
# count  284807.000000
# mean        0.001727
# std         0.041527
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         1.000000
#
# [8 rows x 31 columns]

# %%
# Check for null values
Data.isnull().sum()

##-- There is no Null values in the columns and even we see from the above table as well
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %% [markdown]
# Check for number of data in each class.
#
# As Dataset contains two classes only
# 1. No fraud
# 2. Fraud

# %%
print('No Frauds', round(Data['Class'].value_counts()[0]))
print('Frauds', round(Data['Class'].value_counts()[1]))
# Out:
# No Frauds 284315
# Frauds 492

# %%
print('No Frauds', round(Data['Class'].value_counts()[0]/len(Data) * 100,2), '% of the dataset')
print('Frauds', round(Data['Class'].value_counts()[1]/len(Data) * 100,2), '% of the dataset')
# Out:
# No Frauds 99.83 % of the dataset
# Frauds 0.17 % of the dataset

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Set colors
colors = ['#DF0101']

# Create the count plot without using the palette parameter
sns.countplot(x='Class', data=Data, color=colors[0])  # Use a single color for bars

plt.title('Class Distributions \n (0: No Fraud || 1: Fraud)', fontsize=14)
plt.show()

# %%
# Distributation of the Time and Amount Feature
fig, ax = plt.subplots(1, 2, figsize=(18,3))

amount_val = Data['Amount'].values
time_val = Data['Time'].values

sns.distplot(amount_val, ax=ax[0], color='r')
ax[0].set_title('Distribution of Transaction Amount', fontsize=14)
ax[0].set_xlim([min(amount_val), max(amount_val)])

sns.distplot(time_val, ax=ax[1], color='b')
ax[1].set_title('Distribution of Transaction Time', fontsize=14)
ax[1].set_xlim([min(time_val), max(time_val)])



plt.show()
# Out:
# /tmp/ipykernel_122817/4171762658.py:7: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(amount_val, ax=ax[0], color='r')
# /tmp/ipykernel_122817/4171762658.py:11: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(time_val, ax=ax[1], color='b')

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Set up the figure
fig, ax = plt.subplots(1, 2, figsize=(18, 6))

# Amount distribution
sns.histplot(Data['Amount'], ax=ax[0], color='r', kde=True)
ax[0].set_title('Distribution of Transaction Amount', fontsize=14)
ax[0].set_xlim([min(amount_val), max(amount_val)])

# Time distribution
sns.histplot(Data['Time'], ax=ax[1], color='b', kde=True)
ax[1].set_title('Distribution of Transaction Time', fontsize=14)
ax[1].set_xlim([Data['Time'].min(), Data['Time'].max()])

# Show the plots
plt.show()

# %%
# Since most of our data has already been scaled we should scale the columns that are left to scale (Amount and Time)
from sklearn.preprocessing import StandardScaler, RobustScaler

std_scaler = StandardScaler()
rob_scaler = RobustScaler()

Data['scaled_amount'] = std_scaler.fit_transform(Data['Amount'].values.reshape(-1,1))
Data['scaled_time'] = rob_scaler.fit_transform(Data['Time'].values.reshape(-1,1))

Data.drop(['Time','Amount'], axis=1, inplace=True)

# %%
Data.head(5)
# Out:
#          V1        V2        V3        V4        V5        V6        V7  \
# 0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9       V10  ...       V22       V23       V24       V25  \
# 0  0.098698  0.363787  0.090794  ...  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425 -0.166974  ... -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  0.207643  ...  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024 -0.054952  ...  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  0.753074  ...  0.798278 -0.137458  0.141267 -0.206010
#
#         V26       V27       V28  Class  scaled_amount  scaled_time
# 0 -0.189115  0.133558 -0.021053      0       1.783274    -0.994983
# 1  0.125895 -0.008983  0.014724      0      -0.269825    -0.994983
# 2 -0.139097 -0.055353 -0.059752      0       4.983721    -0.994972
# 3 -0.221929  0.062723  0.061458      0       1.418291    -0.994972
# 4  0.502292  0.219422  0.215153      0       0.670579    -0.994960
#
# [5 rows x 31 columns]

# %%
# Shifting the scaled_amount and scaled_time from back to front

scaled_amount = Data['scaled_amount']
scaled_time = Data['scaled_time']

Data.drop(['scaled_amount', 'scaled_time'], axis=1, inplace=True)
Data.insert(0, 'scaled_amount', scaled_amount)
Data.insert(1, 'scaled_time', scaled_time)

# Aount andTime are Scaled!.

Data.head()
# Out:
#    scaled_amount  scaled_time        V1        V2        V3        V4  \
# 0       1.783274    -0.994983 -1.359807 -0.072781  2.536347  1.378155
# 1      -0.269825    -0.994983  1.191857  0.266151  0.166480  0.448154
# 2       4.983721    -0.994972 -1.358354 -1.340163  1.773209  0.379780
# 3       1.418291    -0.994972 -0.966272 -0.185226  1.792993 -0.863291
# 4       0.670579    -0.994960 -1.158233  0.877737  1.548718  0.403034
#
#          V5        V6        V7        V8  ...       V20       V21       V22  \
# 0 -0.338321  0.462388  0.239599  0.098698  ...  0.251412 -0.018307  0.277838
# 1  0.060018 -0.082361 -0.078803  0.085102  ... -0.069083 -0.225775 -0.638672
# 2 -0.503198  1.800499  0.791461  0.247676  ...  0.524980  0.247998  0.771679
# 3 -0.010309  1.247203  0.237609  0.377436  ... -0.208038 -0.108300  0.005274
# 4 -0.407193  0.095921  0.592941 -0.270533  ...  0.408542 -0.009431  0.798278
#
#         V23       V24       V25       V26       V27       V28  Class
# 0 -0.110474  0.066928  0.128539 -0.189115  0.133558 -0.021053      0
# 1  0.101288 -0.339846  0.167170  0.125895 -0.008983  0.014724      0
# 2  0.909412 -0.689281 -0.327642 -0.139097 -0.055353 -0.059752      0
# 3 -0.190321 -1.175575  0.647376 -0.221929  0.062723  0.061458      0
# 4 -0.137458  0.141267 -0.206010  0.502292  0.219422  0.215153      0
#
# [5 rows x 31 columns]

# %% [markdown]
# As we see from the above result the dataset is highly imbalance.
# 1. Number of Non Fraud : 284315
# 2. Number of Fraud : 492
#
# To handle the imbalanceness I am using resampling techniques:
# 1. Undersampling - random undersampling
# 2. Oversampling - SMOTE
#
# Undersampling - Reduce the number of instances in the majority class.
#
# Oversampling - Generates synthetic examples for the minority class.

# %% [markdown]
# Under sampling Method

# %%
Data = Data.sample(frac=1)

# amount of fraud classes 492 rows.
fraud_data = Data.loc[Data['Class'] == 1]
non_fraud_data = Data.loc[Data['Class'] == 0][:492]

concatenate_data= pd.concat([fraud_data, non_fraud_data])

# Shuffle dataframe rows
shuffle_data = concatenate_data.sample(frac=1, random_state=42)
shuffle_data.head(5)
# Out:
#         scaled_amount  scaled_time        V1        V2        V3        V4  \
# 166969      -0.142528     0.396151 -0.154312  1.064959 -0.575516 -0.593191
# 167184       1.172221     0.397561 -5.961457  5.313382 -6.674320  6.028975
# 33438       -0.296793    -0.557572  1.232524  0.464143 -0.636282  0.843251
# 141259       6.850416    -0.005733 -1.927453  1.827621 -7.019495  5.348303
# 92777        3.813317    -0.242002 -6.133987  2.941499 -5.593986  3.258845
#
#               V5        V6        V7        V8  ...       V20       V21  \
# 166969  1.470816 -1.015275  1.589219 -0.408012  ...  0.074691 -0.111337
# 167184 -1.387560  0.670638 -4.128987 -4.765894  ... -1.116581  5.556642
# 33438   0.119885 -1.035932  0.197951 -0.066563  ... -0.229510 -0.149151
# 141259 -2.739188 -2.107219 -5.015848  1.205868  ...  2.172709  1.376938
# 92777  -5.315512 -0.637328 -4.476488  1.695994  ... -0.815086  0.868340
#
#              V22       V23       V24       V25       V26       V27       V28  \
# 166969  0.019837 -0.234504  0.582215 -0.199343  0.435083  0.170640  0.036443
# 167184 -1.501808  1.355172  0.141093  0.077913  0.473988  0.287129  1.468653
# 33438  -0.434275 -0.029932 -0.092259  0.430545  0.405255 -0.027207  0.035195
# 141259 -0.792017 -0.771414 -0.379574  0.718717  1.111151  1.277707  0.819081
# 92777   0.793736  0.217347 -0.021985  0.145882  0.665088 -1.684186  0.310195
#
#         Class
# 166969      0
# 167184      1
# 33438       0
# 141259      1
# 92777       1
#
# [5 rows x 31 columns]

# %%
print('No Frauds', round(shuffle_data['Class'].value_counts()[0]))
print('Frauds', round(shuffle_data['Class'].value_counts()[1]))
# Out:
# No Frauds 492
# Frauds 492

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Set colors
colors = ['#4FB06D','#DF0101']

# Create the count plot without using the palette parameter
sns.countplot(x='Class', data=shuffle_data, palette=colors)  # Use a single color for bars

plt.title('Class Distributions \n (0: No Fraud || 1: Fraud)', fontsize=14)
plt.show()
# Out:
# /tmp/ipykernel_122817/2336151138.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Class', data=shuffle_data, palette=colors)  # Use a single color for bars

# %%
# Now visualize the data using correlation matrix in order to see which features have high positive or negative correlation
# Create the correlation matrix
sub_sample_corr = shuffle_data.corr()

# Set up the matplotlib figure
f, axs = plt.subplots(1, 1, figsize=(20, 15))

# Heatmap for correlation matrix
sns.heatmap(sub_sample_corr, cmap='RdBu', annot=True, fmt='.2f', ax=axs, cbar=True)

# Titles and labels
axs.set_title('SubSample Correlation Matrix \n (use for reference)', fontsize=14)

plt.tight_layout()  # Adjust layout to avoid overlap
plt.show()

# %% [markdown]
# From above cmap we understand the following data:
# 1. v2,v4,v11 are the highly positively correlated and make the result more towards fraud prediction
# 2. v10,v12,v14 are the highly negatively correlated and make the result more towards non fraud

# %%
f, axes = plt.subplots(ncols=4, figsize=(20,4))

# Negative Correlations with our Class (The lower our feature value the more likely it will be a fraud transation)
sns.boxplot(x='Class', y='V10', data=shuffle_data, palette=colors, ax=axes[0])
axes[0].set_title('V10 vs Class Negative Correlation')

sns.boxplot(x='Class', y='V12', data=shuffle_data, palette=colors, ax=axes[1])
axes[1].set_title('V12 vs Class Negative Correlation')

sns.boxplot(x='Class', y='V14', data=shuffle_data, palette=colors, ax=axes[2])
axes[2].set_title('V14 vs Class Negative Correlation')

sns.boxplot(x='Class', y='V17', data=shuffle_data, palette=colors, ax=axes[3])
axes[3].set_title('V17 vs Class Negative Correlation')

plt.show()
# Out:
# /tmp/ipykernel_122817/2173027629.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Class', y='V10', data=shuffle_data, palette=colors, ax=axes[0])
# /tmp/ipykernel_122817/2173027629.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Class', y='V12', data=shuffle_data, palette=colors, ax=axes[1])
# /tmp/ipykernel_122817/2173027629.py:10: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Class', y='V14', data=shuffle_data, palette=colors, ax=axes[2])
# /tmp/ipykernel_122817/2173027629.py:13: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Class', y='V17', data=shuffle_data, palette=colors, ax=axes[3])

# %%
f, axes = plt.subplots(ncols=4, figsize=(20,4))

# Negative Correlations with our Class (The lower our feature value the more likely it will be a fraud transation)
sns.boxplot(x='Class', y='V2', data=shuffle_data, palette=colors, ax=axes[0])
axes[0].set_title('V2 vs Class Positive Correlation')

sns.boxplot(x='Class', y='V4', data=shuffle_data, palette=colors, ax=axes[1])
axes[1].set_title('V4 vs Class Positive Correlation')

sns.boxplot(x='Class', y='V11', data=shuffle_data, palette=colors, ax=axes[2])
axes[2].set_title('V11 vs Class Positive Correlation')

sns.boxplot(x='Class', y='V19', data=shuffle_data, palette=colors, ax=axes[3])
axes[3].set_title('V19 vs Class Positive Correlation')



plt.show()
# Out:
# /tmp/ipykernel_122817/3843083406.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Class', y='V2', data=shuffle_data, palette=colors, ax=axes[0])
# /tmp/ipykernel_122817/3843083406.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Class', y='V4', data=shuffle_data, palette=colors, ax=axes[1])
# /tmp/ipykernel_122817/3843083406.py:10: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Class', y='V11', data=shuffle_data, palette=colors, ax=axes[2])
# /tmp/ipykernel_122817/3843083406.py:13: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Class', y='V19', data=shuffle_data, palette=colors, ax=axes[3])

# %%
# # -----> V14 Removing Outliers (Highest Negative Correlated with Labels)
v14_fraud = shuffle_data['V14'].loc[shuffle_data['Class'] == 1].values
q25, q75 = np.percentile(v14_fraud, 25), np.percentile(v14_fraud, 75)
print('Quartile 25: {} | Quartile 75: {}'.format(q25, q75))
v14_iqr = q75 - q25
print('iqr: {}'.format(v14_iqr))

v14_cut_off = v14_iqr * 1.5
v14_lower, v14_upper = q25 - v14_cut_off, q75 + v14_cut_off
print('Cut Off: {}'.format(v14_cut_off))
print('V14 Lower: {}'.format(v14_lower))
print('V14 Upper: {}'.format(v14_upper))

outliers = [x for x in v14_fraud if x < v14_lower or x > v14_upper]
print('V10 outliers:{}'.format(outliers))
print('Feature V14 Outliers for Fraud Cases: {}'.format(len(outliers)))
new_shuffle_data = shuffle_data.drop(shuffle_data[(shuffle_data['V14'] > v14_upper) | (shuffle_data['V14'] < v14_lower)].index)
print('Number of Instances after outliers removal: {}'.format(len(new_shuffle_data)))
print('----' * 44)

# -----> V12 removing outliers from fraud transactions
v12_fraud = new_shuffle_data['V12'].loc[new_shuffle_data['Class'] == 1].values
q25, q75 = np.percentile(v12_fraud, 25), np.percentile(v12_fraud, 75)
v12_iqr = q75 - q25

v12_cut_off = v12_iqr * 1.5
v12_lower, v12_upper = q25 - v12_cut_off, q75 + v12_cut_off
print('V12 Lower: {}'.format(v12_lower))
print('V12 Upper: {}'.format(v12_upper))
outliers = [x for x in v12_fraud if x < v12_lower or x > v12_upper]
print('V12 outliers: {}'.format(outliers))
print('Feature V12 Outliers for Fraud Cases: {}'.format(len(outliers)))
new_shuffle_data = new_shuffle_data.drop(new_shuffle_data[(new_shuffle_data['V12'] > v12_upper) | (new_shuffle_data['V12'] < v12_lower)].index)
print('Number of Instances after outliers removal: {}'.format(len(new_shuffle_data)))
print('----' * 44)


# Removing outliers V10 Feature
v10_fraud = new_shuffle_data['V10'].loc[new_shuffle_data['Class'] == 1].values
q25, q75 = np.percentile(v10_fraud, 25), np.percentile(v10_fraud, 75)
v10_iqr = q75 - q25

v10_cut_off = v10_iqr * 1.5
v10_lower, v10_upper = q25 - v10_cut_off, q75 + v10_cut_off
print('V10 Lower: {}'.format(v10_lower))
print('V10 Upper: {}'.format(v10_upper))
outliers = [x for x in v10_fraud if x < v10_lower or x > v10_upper]
print('V10 outliers: {}'.format(outliers))
print('Feature V10 Outliers for Fraud Cases: {}'.format(len(outliers)))
new_shuffle_data = new_shuffle_data.drop(new_shuffle_data[(new_shuffle_data['V10'] > v10_upper) | (new_shuffle_data['V10'] < v10_lower)].index)
print('Number of Instances after outliers removal: {}'.format(len(new_shuffle_data)))
# Out:
# Quartile 25: -9.692722964972386 | Quartile 75: -4.282820849486865
# iqr: 5.409902115485521
# Cut Off: 8.114853173228282
# V14 Lower: -17.807576138200666
# V14 Upper: 3.8320323237414167
# V10 outliers:[-18.0499976898594, -18.4937733551053, -19.2143254902614, -18.8220867423816]
# Feature V14 Outliers for Fraud Cases: 4
# Number of Instances after outliers removal: 976
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# V12 Lower: -17.3430371579634
# V12 Upper: 5.776973384895937
# V12 outliers: [-18.6837146333443, -18.4311310279993, -18.5536970096458, -18.0475965708216]
# Feature V12 Outliers for Fraud Cases: 4
# Number of Instances after outliers removal: 972
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# V10 Lower: -14.89885463232024
# V10 Upper: 4.92033495834214
# V10 outliers: [-15.5637913387301, -20.9491915543611, -16.6011969664137, -16.2556117491401, -18.9132433348732, -15.1237521803455, -16.6496281595399, -23.2282548357516, -15.2318333653018, -17.1415136412892, -22.1870885620007, -22.1870885620007, -14.9246547735487, -15.3460988468775, -19.836148851696, -24.5882624372475, -24.4031849699728, -18.2711681738888, -16.3035376590131, -15.1241628144947, -22.1870885620007, -15.2399619587112, -22.1870885620007, -16.7460441053944, -14.9246547735487, -15.2399619587112, -15.5637913387301]
# Feature V10 Outliers for Fraud Cases: 27
# Number of Instances after outliers removal: 941

# %%
# Set up the figure size and styling
plt.figure(figsize=(15, 5))

# Plotting V14 Distribution
plt.subplot(1, 3, 1)
sns.histplot(new_shuffle_data[new_shuffle_data['Class'] == 1]['V14'], bins=50, kde=True, color='orange')
plt.title('V14 Distribution\n(Fraud Transactions)')

# Plotting V12 Distribution
plt.subplot(1, 3, 2)
sns.histplot(new_shuffle_data[new_shuffle_data['Class'] == 1]['V12'], bins=50, kde=True, color='green')
plt.title('V12 Distribution\n(Fraud Transactions)')

# Plotting V10 Distribution
plt.subplot(1, 3, 3)
sns.histplot(new_shuffle_data[new_shuffle_data['Class'] == 1]['V10'], bins=50, kde=True, color='purple')
plt.title('V10 Distribution\n(Fraud Transactions)')

plt.tight_layout()
plt.show()

# %%
X_features = shuffle_data.drop('Class',axis=1)
Y_labels = shuffle_data['Class']

# %%
X_features
# Out:
#         scaled_amount  scaled_time         V1         V2         V3        V4  \
# 166969      -0.142528     0.396151  -0.154312   1.064959  -0.575516 -0.593191
# 167184       1.172221     0.397561  -5.961457   5.313382  -6.674320  6.028975
# 33438       -0.296793    -0.557572   1.232524   0.464143  -0.636282  0.843251
# 141259       6.850416    -0.005733  -1.927453   1.827621  -7.019495  5.348303
# 92777        3.813317    -0.242002  -6.133987   2.941499  -5.593986  3.258845
# ...               ...          ...        ...        ...        ...       ...
# 81609       19.109341    -0.301707  -2.326922  -3.348439  -3.513408  3.175060
# 42609        0.857682    -0.511308  -6.498086   4.750515  -8.966558  7.098854
# 64591        0.250122    -0.393285   1.338595  -0.818574   0.621653 -0.925854
# 8312        -0.293440    -0.864672   0.378275   3.914797  -5.726872  6.094141
# 15506        1.089779    -0.678967 -21.885434  12.930505 -24.098872  6.203314
#
#                V5        V6         V7         V8  ...       V19       V20  \
# 166969   1.470816 -1.015275   1.589219  -0.408012  ... -0.064888  0.074691
# 167184  -1.387560  0.670638  -4.128987  -4.765894  ...  0.936966 -1.116581
# 33438    0.119885 -1.035932   0.197951  -0.066563  ... -0.711327 -0.229510
# 141259  -2.739188 -2.107219  -5.015848   1.205868  ...  0.844060  2.172709
# 92777   -5.315512 -0.637328  -4.476488   1.695994  ...  1.763611 -0.815086
# ...           ...       ...        ...        ...  ...       ...       ...
# 81609   -2.815137 -0.203363  -0.892144   0.333226  ...  0.595629  3.209171
# 42609   -6.958376 -2.822126 -10.333406   4.031907  ...  1.951890  0.568338
# 64591   -1.057655  0.101151  -1.108708   0.130461  ...  0.829690  0.187633
# 8312     1.698875 -2.807314  -0.591118  -0.123496  ... -2.005477  0.440439
# 15506  -16.466099 -4.459842 -16.519836  14.535565  ...  1.104355  1.611998
#
#              V21       V22       V23       V24       V25       V26       V27  \
# 166969 -0.111337  0.019837 -0.234504  0.582215 -0.199343  0.435083  0.170640
# 167184  5.556642 -1.501808  1.355172  0.141093  0.077913  0.473988  0.287129
# 33438  -0.149151 -0.434275 -0.029932 -0.092259  0.430545  0.405255 -0.027207
# 141259  1.376938 -0.792017 -0.771414 -0.379574  0.718717  1.111151  1.277707
# 92777   0.868340  0.793736  0.217347 -0.021985  0.145882  0.665088 -1.684186
# ...          ...       ...       ...       ...       ...       ...       ...
# 81609   1.226648 -0.695902 -1.478490 -0.061553  0.236155  0.531911  0.302324
# 42609   2.158143  0.111510  0.216414  0.584661  0.760360  0.081972  1.415068
# 64591   0.393297  0.996330 -0.246295 -0.477521  0.502879 -0.016508  0.027365
# 8312    0.149896 -0.601967 -0.613724 -0.403114  1.568445  0.521884  0.527938
# 15506   1.762232 -1.579055 -0.951043  0.134565  1.507110 -0.222671  1.527655
#
#              V28
# 166969  0.036443
# 167184  1.468653
# 33438   0.035195
# 141259  0.819081
# 92777   0.310195
# ...          ...
# 81609   0.536375
# 42609   0.035124
# 64591   0.011884
# 8312    0.411910
# 15506   0.453699
#
# [984 rows x 30 columns]

# %%
Y_labels
# Out:
# 166969    0
# 167184    1
# 33438     0
# 141259    1
# 92777     1
#          ..
# 81609     1
# 42609     1
# 64591     0
# 8312      1
# 15506     1
# Name: Class, Length: 984, dtype: int64

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X_features, Y_labels, test_size=0.2, random_state=42)

# %%
# Use GridSearchCV to find the best parameters.
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score
from sklearn.svm import SVC
from sklearn.model_selection import cross_val_score


# Support Vector Classifier
svc_params = {'C': [0.5, 0.7, 0.9, 1], 'kernel': ['rbf', 'poly', 'sigmoid', 'linear']}
grid_svc = GridSearchCV(SVC(probability=True), svc_params)
grid_svc.fit(X_train, y_train)

# SVC best estimator
svc = grid_svc.best_estimator_
print('Support Vector Classifier Best Params: ', grid_svc.best_params_)
svc_score = cross_val_score(svc, X_train, y_train, cv=5)
print('Support Vector Classifier Cross Validation Score', round(svc_score.mean() * 100, 2).astype(str) + '%')
# Out:
# Support Vector Classifier Best Params:  {'C': 0.9, 'kernel': 'linear'}
# Support Vector Classifier Cross Validation Score 93.27%

# %%
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score

# Make predictions on the test set
y_pred = svc.predict(X_test)

# Compute the confusion matrix
cm = confusion_matrix(y_test, y_pred)

# Calculate accuracy
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy of the model: {accuracy:.2f}")

# Print the classification report
print(classification_report(y_test, y_pred))

# Plot the confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=['No Fraud', 'Fraud'], yticklabels=['No Fraud', 'Fraud'])
plt.ylabel('Actual')
plt.xlabel('Predicted')
plt.title('Confusion Matrix')
plt.show()
# Out:
# Accuracy of the model: 0.94
#               precision    recall  f1-score   support
#
#            0       0.90      0.99      0.94        87
#            1       0.99      0.91      0.95       110
#
#     accuracy                           0.94       197
#    macro avg       0.94      0.95      0.94       197
# weighted avg       0.95      0.94      0.94       197

# %%
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score, precision_score, recall_score, f1_score
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)

# Print metrics
print(f"Accuracy of the model: {accuracy:.2f}")
print(f"Precision: {precision:.2f}")
print(f"Recall: {recall:.2f}")
print(f"F1 Score: {f1:.2f}")
# Out:
# Accuracy of the model: 0.94
# Precision: 0.99
# Recall: 0.91
# F1 Score: 0.95

# %%
from sklearn.metrics import roc_curve, roc_auc_score
y_scores = svc.predict_proba(X_test)[:, 1]  # Probabilities for the positive class

# Step 5: Compute ROC curve and AUC
fpr, tpr, thresholds = roc_curve(y_test, y_scores)
auc = roc_auc_score(y_test, y_scores)

print('auc:',auc)

# Step 6: Plot ROC curve
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, color='blue', label='ROC curve (AUC = {:.2f})'.format(auc))
plt.plot([0, 1], [0, 1], color='red', linestyle='--')  # Diagonal line
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic')
plt.legend(loc='lower right')
plt.grid()
plt.show()
# Out:
# auc: 0.9845350052246604

# %% [markdown]
# ## Artificial Neural Network

# %%
pip install tensorflow==2.15
# Out:
# Requirement already satisfied: tensorflow==2.15 in /home/it/miniconda3/envs/myenv311/lib/python3.10/site-packages (2.15.0)
# Requirement already satisfied: absl-py>=1.0.0 in /home/it/miniconda3/envs/myenv311/lib/python3.10/site-packages (from tensorflow==2.15) (2.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in /home/it/miniconda3/envs/myenv311/lib/python3.10/site-packages (from tensorflow==2.15) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in /home/it/miniconda3/envs/myenv311/lib/python3.10/site-packages (from tensorflow==2.15) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /home/it/miniconda3/envs/myenv311/lib/python3.10/site-packages (from tensorflow==2.15) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /home/it/miniconda3/envs/myenv311/lib/python3.10/site-packages (from tensorflow==2.15) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in /home/it/miniconda3/envs/myenv311/lib/python3.10/site-packages (from tensorflow==2.15) (3.11.0)
# Requirement already satisfied: libclang>=13.0.0 in /home/it/miniconda3/envs/myenv311/lib/python3.10/site-packages (from tensorflow==2.15) (18.1.1)
# Requirement already satisfied: ml-dtypes~=0.2.0 in /home/it/miniconda3/envs/myenv311/lib/python3.10/site-packages (from tensorflow==2.15) (0.2.0)
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in /home/it/miniconda3/envs/myenv311/lib/python3.10/site-packages (from tensorflow==2.15) (1.26.4)
# Requirement already satisfied: opt-einsum>=2.3.2 in /home/it/miniconda3/envs/myenv311/lib/python3.10/site-packages (from tensorflow==2.15) (3.3.0)
# Requirement already satisfied: packaging in /home/it/miniconda3/envs/myenv311/lib/python3.10/site-packages (from tensorflow==2.15) (24.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /home/it/miniconda3/envs/myenv311/lib/python3.10/site-packages (from tensorflow==2.15) (4.25.4)
# Requirement already satisfied: setuptools in /home/it/miniconda3/envs/myenv311/lib/python3.10/site-packages (from tensorflow==2.15) (72.1.0)
# Requirement already satisfied: six>=1.12.0 in /home/it/miniconda3/envs/myenv311/lib/python3.10/site-packages (from tensorflow==2.15) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /home/it/miniconda3/envs/myenv311/lib/python3.10/site-packages (from tensorflow==2.15) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /home/it/miniconda3/envs/myenv311/lib/python3.10/site-packages (from tensorflow==2.15) (4.12.2)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in /home/it/miniconda3/envs/myenv311/lib/python3.10/site-packages (from tensorflow==2.15) (1.14.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /home/it/miniconda3/envs/myenv311/lib/python3.10/site-packages (from tensorflow==2.15) (0.37.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /home/it/miniconda3/envs/myenv311/lib/python3.10/site-packages (from tensorflow==2.15) (1.65.4)
# Requirement already satisfied: tensorboard<2.16,>=2.15 in /home/it/miniconda3/envs/myenv311/lib/python3.10/site-packages (from tensorflow==2.15) (2.15.2)
# Requirement already satisfied: tensorflow-estimator<2.16,>=2.15.0 in /home/it/miniconda3/envs/myenv311/lib/python3.10/site-packages (from tensorflow==2.15) (2.15.0)
# Requirement already satisfied: keras<2.16,>=2.15.0 in /home/it/miniconda3/envs/myenv311/lib/python3.10/site-packages (from tensorflow==2.15) (2.15.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /home/it/miniconda3/envs/myenv311/lib/python3.10/site-packages (from astunparse>=1.6.0->tensorflow==2.15) (0.43.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /home/it/miniconda3/envs/myenv311/lib/python3.10/site-packages (from tensorboard<2.16,>=2.15->tensorflow==2.15) (2.33.0)
# Requirement already satisfied: google-auth-oauthlib<2,>=0.5 in /home/it/miniconda3/envs/myenv311/lib/python3.10/site-packages (from tensorboard<2.16,>=2.15->tensorflow==2.15) (1.2.1)
# Requirement already satisfied: markdown>=2.6.8 in /home/it/miniconda3/envs/myenv311/lib/python3.10/site-packages (from tensorboard<2.16,>=2.15->tensorflow==2.15) (3.6)
# Requirement already satisfied: requests<3,>=2.21.0 in /home/it/miniconda3/envs/myenv311/lib/python3.10/site-packages (from tensorboard<2.16,>=2.15->tensorflow==2.15) (2.32.3)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /home/it/miniconda3/envs/myenv311/lib/python3.10/site-packages (from tensorboard<2.16,>=2.15->tensorflow==2.15) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /home/it/miniconda3/envs/myenv311/lib/python3.10/site-packages (from tensorboard<2.16,>=2.15->tensorflow==2.15) (3.0.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /home/it/miniconda3/envs/myenv311/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow==2.15) (5.4.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /home/it/miniconda3/envs/myenv311/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow==2.15) (0.4.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /home/it/miniconda3/envs/myenv311/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow==2.15) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /home/it/miniconda3/envs/myenv311/lib/python3.10/site-packages (from google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow==2.15) (2.0.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/it/miniconda3/envs/myenv311/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow==2.15) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/it/miniconda3/envs/myenv311/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow==2.15) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/it/miniconda3/envs/myenv311/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow==2.15) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in /home/it/miniconda3/envs/myenv311/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow==2.15) (2024.7.4)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /home/it/miniconda3/envs/myenv311/lib/python3.10/site-packages (from werkzeug>=1.0.1->tensorboard<2.16,>=2.15->tensorflow==2.15) (2.1.5)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /home/it/miniconda3/envs/myenv311/lib/python3.10/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow==2.15) (0.6.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /home/it/miniconda3/envs/myenv311/lib/python3.10/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow==2.15) (3.2.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam
#from tensorflow.keras.metrics import categorical_crossentropy
# Out:
# 2024-10-19 05:21:31.791431: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-10-19 05:21:31.822274: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-10-19 05:21:31.822304: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-10-19 05:21:31.823097: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-10-19 05:21:31.828333: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
X_train.shape
# Out:
# (787, 30)

# %%
model = Sequential()
model.add(Dense(units = 30, activation='relu', input_shape=(X_train.shape[1],)))
model.add(Dense(units=10, activation='relu'))
model.add(Dense(1, activation='sigmoid'))
# Out:
# 2024-10-19 00:36:48.020439: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1929] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 1129 MB memory:  -> device: 0, name: NVIDIA RTX A4000, pci bus id: 0000:65:00.0, compute capability: 8.6

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 30)                930
#
#  dense_1 (Dense)             (None, 10)                310
#
#  dense_2 (Dense)             (None, 1)                 11
#
# =================================================================
# Total params: 1251 (4.89 KB)
# Trainable params: 1251 (4.89 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Compile the model
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Train the model
history = model.fit(X_train, y_train, epochs=50, batch_size=40, validation_split=0.2)
# Out:
# Epoch 1/50
# 2024-10-19 00:36:51.866947: I external/local_xla/xla/service/service.cc:168] XLA service 0x7ba16d8a56e0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2024-10-19 00:36:51.866973: I external/local_xla/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA RTX A4000, Compute Capability 8.6
# 2024-10-19 00:36:51.871677: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2024-10-19 00:36:51.886183: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:454] Loaded cuDNN version 8907
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1729278412.013121   78148 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 16/16 [==============================] - 2s 14ms/step - loss: 1.7156 - accuracy: 0.5644 - val_loss: 0.7505 - val_accuracy: 0.7215
# Epoch 2/50
# 16/16 [==============================] - 0s 8ms/step - loss: 0.4661 - accuracy: 0.8108 - val_loss: 0.4856 - val_accuracy: 0.8354
# Epoch 3/50
# 16/16 [==============================] - 0s 8ms/step - loss: 0.3669 - accuracy: 0.8617 - val_loss: 0.4250 - val_accuracy: 0.8671
# 16/16 [==============================] - 0s 7ms/step - loss: 0.0758 - accuracy: 0.9666 - val_loss: 0.1361 - val_accuracy: 0.9620
# Epoch 46/50
# 16/16 [==============================] - 0s 7ms/step - loss: 0.0746 - accuracy: 0.9650 - val_loss: 0.1350 - val_accuracy: 0.9620
# Epoch 47/50
# 16/16 [==============================] - 0s 8ms/step - loss: 0.0733 - accuracy: 0.9666 - val_loss: 0.1366 - val_accuracy: 0.9620
# Epoch 48/50
# 16/16 [==============================] - 0s 7ms/step - loss: 0.0724 - accuracy: 0.9666 - val_loss: 0.1374 - val_accuracy: 0.9620
# Epoch 49/50
# 16/16 [==============================] - 0s 7ms/step - loss: 0.0708 - accuracy: 0.9650 - val_loss: 0.1379 - val_accuracy: 0.9620
# Epoch 50/50
# 16/16 [==============================] - 0s 7ms/step - loss: 0.0699 - accuracy: 0.9650 - val_loss: 0.1380 - val_accuracy: 0.9620

# %%
# Plot training & validation loss and accuracy
plt.figure(figsize=(14, 5))

# Loss plot
plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

# Accuracy plot
plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout()
plt.show()

# %%
# Evaluate the model
loss, accuracy = model.evaluate(X_test, y_test)
print(f"Test accuracy: {accuracy:.2f}")

# Make predictions
y_pred = model.predict(X_test)
y_pred = (y_pred > 0.5).astype(int)  # Convert probabilities to binary predictions

# Confusion matrix and classification report
cm = confusion_matrix(y_test, y_pred)
print(classification_report(y_test, y_pred))

# Calculate precision, recall, and F1 score
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)


# Plot confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=['No Fraud', 'Fraud'], yticklabels=['No Fraud', 'Fraud'])
plt.ylabel('Actual')
plt.xlabel('Predicted')
plt.title('Confusion Matrix')
plt.show()
# Out:
# 7/7 [==============================] - 0s 4ms/step - loss: 0.1381 - accuracy: 0.9543
# Test accuracy: 0.95
# 7/7 [==============================] - 0s 2ms/step
#               precision    recall  f1-score   support
#
#            0       0.92      0.98      0.95        87
#            1       0.98      0.94      0.96       110
#
#     accuracy                           0.95       197
#    macro avg       0.95      0.96      0.95       197
# weighted avg       0.96      0.95      0.95       197

# %%
print(f"Accuracy: {accuracy:.2f}")
print(f"Precision: {precision:.2f}")
print(f"Recall: {recall:.2f}")
print(f"F1 Score: {f1:.2f}")
# Out:
# Accuracy: 0.95
# Precision: 0.98
# Recall: 0.94
# F1 Score: 0.96

# %%
# Get predicted probabilities for the positive class
y_pred_prob_ann = model.predict(X_test)  # This will return probabilities

# Compute ROC curve and AUC for ANN
fpr_ann, tpr_ann, _ = roc_curve(y_test, y_pred_prob_ann)
auc_ann = roc_auc_score(y_test, y_pred_prob_ann)
print("ANN AUC:", auc_ann)

# Plot ROC curve
plt.figure()
plt.plot(fpr_ann, tpr_ann, label='ANN ROC curve (AUC = {:.2f})'.format(auc_ann))
plt.plot([0, 1], [0, 1], 'r--')  # Diagonal line
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve for ANN')
plt.legend(loc='lower right')
plt.show()
# Out:
# 7/7 [==============================] - 0s 1ms/step
# ANN AUC: 0.9866248693834901

# %% [markdown]
# ## Starting Quantum Implementation

# %% [markdown]
# ## Model 1 Quantum Neural Network

# %%
pip install pennylane==0.37.0

# %%
import pennylane as qml
from silence_tensorflow import silence_tensorflow

silence_tensorflow()

# As pennylane works with doubles while tensorflow uses ordinary floats, therefore convert the tensorflow into doubles
tf.keras.backend.set_floatx('float64')

# %% [markdown]
# ## Angle Embedding Technique
#
# In angle embedding, number of qubits used for quantum circuit is equal to number of features available in the dataset. Our dataset contains the 30 features. In Order to avoid the program crash, we will reduce the number of features till 4 componets using PCA techniques. This techniques helps in maintaing the important features of the dataset.

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=4)
X_train_pca = pca.fit_transform(X_train)
X_test_pca = pca.transform(X_test)

# %%
X_train_pca.shape
# Out:
# (787, 4)

# %%
nqubits  = 4
dev = qml.device("lightning.qubit", wires=nqubits)
@qml.qnode(dev, interface="tf",diff_method="adjoint")

def qnode(inputs, weights):
    qml.AngleEmbedding(inputs, wires=range(nqubits))
    qml.BasicEntanglerLayers(weights=weights, wires=range(nqubits))
    return [qml.expval(qml.PauliZ(wires=[0]))]

# %%
nlayer = 1
weight_shapes = {"weights": (nlayer, nqubits)}
qlayer = qml.qnn.KerasLayer(qnode, weight_shapes, output_dim=1)

# %%
# Function to draw the quantum circuit
def draw_circuit():
    inputs = np.random.rand(nqubits)  # Dummy input for the circuit
    weights = np.random.rand(nlayer, nqubits)  # Random weights for 2 layers
    fig,ax = qml.draw_mpl(qnode)(inputs, weights)
    plt.show()


draw_circuit()

# %%
quantum_model = tf.keras.models.Sequential([qlayer])
opt = tf.keras.optimizers.Adam(learning_rate=0.005)
quantum_model.compile(opt,loss='binary_crossentropy',metrics=['accuracy'])

# %%
history = quantum_model.fit(X_train_pca, y_train, epochs=50, batch_size=40, validation_split=0.2)
# Out:
# Epoch 1/50
# 16/16 [==============================] - 4s 265ms/step - loss: 3.6479 - accuracy: 0.5390 - val_loss: 3.7183 - val_accuracy: 0.5190
# Epoch 2/50
# 16/16 [==============================] - 4s 270ms/step - loss: 3.6531 - accuracy: 0.5374 - val_loss: 3.6802 - val_accuracy: 0.5190
# Epoch 3/50
# 16/16 [==============================] - 4s 254ms/step - loss: 3.6525 - accuracy: 0.5374 - val_loss: 3.6823 - val_accuracy: 0.5190
# Epoch 4/50
# 16/16 [==============================] - 4s 262ms/step - loss: 3.6530 - accuracy: 0.5374 - val_loss: 3.6420 - val_accuracy: 0.5190
# Epoch 5/50
# 16/16 [==============================] - 4s 254ms/step - loss: 3.6562 - accuracy: 0.5358 - val_loss: 3.6860 - val_accuracy: 0.5190
# Epoch 6/50
# 16/16 [==============================] - 4s 257ms/step - loss: 3.6470 - accuracy: 0.5358 - val_loss: 3.6509 - val_accuracy: 0.5190
# Epoch 7/50
# 16/16 [==============================] - 4s 274ms/step - loss: 3.6608 - accuracy: 0.5358 - val_loss: 3.6960 - val_accuracy: 0.5190
# Epoch 8/50
# 16/16 [==============================] - 4s 284ms/step - loss: 3.6470 - accuracy: 0.5358 - val_loss: 3.6808 - val_accuracy: 0.5190
# Epoch 9/50
# 16/16 [==============================] - 4s 269ms/step - loss: 3.6628 - accuracy: 0.5358 - val_loss: 3.6087 - val_accuracy: 0.5190
# Epoch 10/50
# 16/16 [==============================] - 4s 245ms/step - loss: 3.6611 - accuracy: 0.5358 - val_loss: 3.6031 - val_accuracy: 0.5253
# Epoch 11/50
# 16/16 [==============================] - 4s 252ms/step - loss: 3.6619 - accuracy: 0.5374 - val_loss: 3.6028 - val_accuracy: 0.5253
# Epoch 12/50
# 16/16 [==============================] - 4s 250ms/step - loss: 3.6613 - accuracy: 0.5374 - val_loss: 3.6038 - val_accuracy: 0.5190
# Epoch 13/50
# 16/16 [==============================] - 4s 229ms/step - loss: 3.6622 - accuracy: 0.5374 - val_loss: 3.6057 - val_accuracy: 0.5190
# Epoch 14/50
# 16/16 [==============================] - 4s 271ms/step - loss: 3.6614 - accuracy: 0.5374 - val_loss: 3.6024 - val_accuracy: 0.5190
# Epoch 15/50
# 16/16 [==============================] - 4s 248ms/step - loss: 3.6621 - accuracy: 0.5358 - val_loss: 3.6031 - val_accuracy: 0.5253
# Epoch 36/50
# 16/16 [==============================] - 4s 252ms/step - loss: 3.6615 - accuracy: 0.5374 - val_loss: 3.6036 - val_accuracy: 0.5190
# Epoch 37/50
# 16/16 [==============================] - 4s 240ms/step - loss: 3.6620 - accuracy: 0.5358 - val_loss: 3.6032 - val_accuracy: 0.5253
# Epoch 38/50
# 16/16 [==============================] - 4s 245ms/step - loss: 3.6612 - accuracy: 0.5374 - val_loss: 3.6120 - val_accuracy: 0.5190
# Epoch 39/50
# 16/16 [==============================] - 4s 238ms/step - loss: 3.6624 - accuracy: 0.5358 - val_loss: 3.6043 - val_accuracy: 0.5190
# Epoch 40/50
# 16/16 [==============================] - 4s 246ms/step - loss: 3.6651 - accuracy: 0.5358 - val_loss: 3.6026 - val_accuracy: 0.5253
# Epoch 41/50
# 16/16 [==============================] - 4s 240ms/step - loss: 3.6620 - accuracy: 0.5374 - val_loss: 3.6043 - val_accuracy: 0.5190
# Epoch 42/50
# 16/16 [==============================] - 4s 252ms/step - loss: 3.6620 - accuracy: 0.5374 - val_loss: 3.6029 - val_accuracy: 0.5253
# Epoch 43/50
# 16/16 [==============================] - 4s 227ms/step - loss: 3.6624 - accuracy: 0.5358 - val_loss: 3.6136 - val_accuracy: 0.5190
# Epoch 44/50
# 16/16 [==============================] - 4s 245ms/step - loss: 3.6610 - accuracy: 0.5374 - val_loss: 3.6007 - val_accuracy: 0.5253
# Epoch 45/50
# 16/16 [==============================] - 4s 240ms/step - loss: 3.6621 - accuracy: 0.5374 - val_loss: 3.6012 - val_accuracy: 0.5190
# Epoch 46/50
# 16/16 [==============================] - 4s 237ms/step - loss: 3.6608 - accuracy: 0.5374 - val_loss: 3.6087 - val_accuracy: 0.5190
# Epoch 47/50
# 16/16 [==============================] - 4s 264ms/step - loss: 3.6656 - accuracy: 0.5358 - val_loss: 3.6187 - val_accuracy: 0.5190
# Epoch 48/50
# 16/16 [==============================] - 4s 234ms/step - loss: 3.6648 - accuracy: 0.5342 - val_loss: 3.6069 - val_accuracy: 0.5253
# Epoch 49/50
# 16/16 [==============================] - 4s 264ms/step - loss: 3.6656 - accuracy: 0.5342 - val_loss: 3.6011 - val_accuracy: 0.5253
# Epoch 50/50
# 16/16 [==============================] - 4s 234ms/step - loss: 3.6631 - accuracy: 0.5374 - val_loss: 3.6424 - val_accuracy: 0.5190

# %%
# Plot training & validation loss and accuracy
plt.figure(figsize=(14, 5))

# Loss plot
plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

# Accuracy plot
plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout()
plt.show()

# %%
# Evaluate the model
loss, accuracy = quantum_model.evaluate(X_test_pca, y_test)
print(f'Test loss: {loss}, Test accuracy: {accuracy}')
# Out:
# 7/7 [==============================] - 1s 71ms/step - loss: 5.0247 - accuracy: 0.4264
# Test loss: 5.024673873095343, Test accuracy: 0.4263959390862944

# %%
# Make predictions on the test set
y_pred_prob = quantum_model.predict(X_test_pca)
y_pred = (y_pred_prob > 0.5).astype(int)  # Convert probabilities to binary labels
# Out:
# 7/7 [==============================] - 1s 85ms/step

# %%
# Generate the confusion matrix
cm = confusion_matrix(y_test, y_pred)

# Plot the confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()

# %%
# Print accuracy, precision, recall, and F1-score
print("Classification Report:")
print(classification_report(y_test, y_pred))
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.43      0.90      0.58        87
#            1       0.40      0.05      0.10       110
#
#     accuracy                           0.43       197
#    macro avg       0.41      0.48      0.34       197
# weighted avg       0.41      0.43      0.31       197

# %%
print("Quantum Neural Network Accuracy:", accuracy*100)
# Out:
# Quantum Neural Network Accuracy: 42.63959390862944

# %%
from sklearn.metrics import precision_score, recall_score, f1_score

# Calculate precision, recall, and f1-score
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)

print(f'Accuracy: {accuracy:.4f}')
print(f'Precision: {precision:.4f}')
print(f'Recall: {recall:.4f}')
print(f'F1 Score: {f1:.4f}')
# Out:
# Accuracy: 0.4264
# Precision: 0.4000
# Recall: 0.0545
# F1 Score: 0.0960

# %%
# Get predicted probabilities for the positive class
y_pred_prob_qnn = quantum_model.predict(X_test_pca)  # This will return probabilities

# Compute ROC curve and AUC for ANN
fpr_qnn, tpr_qnn, _ = roc_curve(y_test, y_pred_prob_qnn)
auc_qnn = roc_auc_score(y_test, y_pred_prob_qnn)
print("QNN AUC:", auc_qnn)

# Plot ROC curve
plt.figure()
plt.plot(fpr_qnn, tpr_qnn, label='QNN ROC curve (AUC = {:.2f})'.format(auc_qnn))
plt.plot([0, 1], [0, 1], 'r--')  # Diagonal line
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve for QNN')
plt.legend(loc='lower right')
plt.show()
# Out:
# 7/7 [==============================] - 0s 58ms/step
# QNN AUC: 0.3536050156739812

# %% [markdown]
# ## Amplitude Embedding
# PCA is not required for this embedding method. Using this encoding method, Number of qubits will be equal to logarthmic base 2 of number of features in the dataset. It means we can use 5 qubits because the number of features in dataset is 30.

# %%
import pennylane as qml
from silence_tensorflow import silence_tensorflow

silence_tensorflow()
tf.keras.backend.set_floatx('float64')
nqubits  = 5
dev = qml.device("lightning.qubit", wires=nqubits)
@qml.qnode(dev, interface="tf",diff_method="adjoint")

@qml.qnode(dev)
def qnode(inputs, weights):
    qml.AmplitudeEmbedding(features = [a for a in inputs], wires=range(nqubits), normalize = True, pad_with = 0.)
    qml.BasicEntanglerLayers(weights, wires=range(nqubits))
    return [qml.expval(qml.PauliZ(wires=[0]))]

# %%
nlayer = 1
weight_shapes = {"weights": (nlayer, nqubits)}

qlayer = qml.qnn.KerasLayer(qnode, weight_shapes, output_dim=nqubits)

# %%
# Function to draw the quantum circuit
def draw_circuit():
    inputs = np.random.rand(nqubits)  # Dummy input for the circuit
    weights = np.random.rand(nlayer, nqubits)  # Random weights for 2 layers
    fig,ax = qml.draw_mpl(qnode)(inputs, weights)
    plt.show()


draw_circuit()

# %%
quantum_model2 = tf.keras.models.Sequential([qlayer])
opt = tf.keras.optimizers.Adam(learning_rate=0.005)
quantum_model2.compile(opt,loss='binary_crossentropy',metrics=['accuracy'])

# %%
history = quantum_model2.fit(X_train, y_train, epochs=50, batch_size=40, validation_split=0.2)
# Out:
# Epoch 1/50
# 16/16 [==============================] - 4s 224ms/step - loss: 1.3175 - accuracy: 0.5262 - val_loss: 1.0144 - val_accuracy: 0.5063
# Epoch 2/50
# 16/16 [==============================] - 4s 226ms/step - loss: 1.1387 - accuracy: 0.5294 - val_loss: 0.9760 - val_accuracy: 0.5127
# Epoch 3/50
# 16/16 [==============================] - 3s 214ms/step - loss: 1.0403 - accuracy: 0.5326 - val_loss: 1.0128 - val_accuracy: 0.5127
# 16/16 [==============================] - 4s 282ms/step - loss: 0.7557 - accuracy: 0.6375 - val_loss: 0.8728 - val_accuracy: 0.6646
# Epoch 44/50
# 16/16 [==============================] - 4s 222ms/step - loss: 0.7555 - accuracy: 0.6359 - val_loss: 0.8727 - val_accuracy: 0.6709
# Epoch 45/50
# 16/16 [==============================] - 4s 274ms/step - loss: 0.7555 - accuracy: 0.6407 - val_loss: 0.8724 - val_accuracy: 0.6709
# Epoch 46/50
# 16/16 [==============================] - 3s 221ms/step - loss: 0.7556 - accuracy: 0.6423 - val_loss: 0.8723 - val_accuracy: 0.6709
# Epoch 47/50
# 16/16 [==============================] - 4s 229ms/step - loss: 0.7560 - accuracy: 0.6343 - val_loss: 0.8733 - val_accuracy: 0.6582
# Epoch 48/50
# 16/16 [==============================] - 4s 224ms/step - loss: 0.7556 - accuracy: 0.6359 - val_loss: 0.8726 - val_accuracy: 0.6709
# Epoch 49/50
# 16/16 [==============================] - 3s 209ms/step - loss: 0.7556 - accuracy: 0.6391 - val_loss: 0.8727 - val_accuracy: 0.6709
# Epoch 50/50
# 16/16 [==============================] - 3s 203ms/step - loss: 0.7555 - accuracy: 0.6391 - val_loss: 0.8728 - val_accuracy: 0.6709

# %%
# Plot training & validation loss and accuracy
plt.figure(figsize=(14, 5))

# Loss plot
plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

# Accuracy plot
plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout()
plt.show()

# %%
# Evaluate the model
loss, accuracy = quantum_model2.evaluate(X_test, y_test)
print(f'Test loss: {loss}, Test accuracy: {accuracy}')
# Out:
# 7/7 [==============================] - 0s 39ms/step - loss: 0.9380 - accuracy: 0.6091
# Test loss: 0.938021221741807, Test accuracy: 0.6091370558375635

# %%
# Make predictions on the test set
y_pred_prob = quantum_model2.predict(X_test)
y_pred = (y_pred_prob > 0.5).astype(int)  # Convert probabilities to binary labels
# Out:
# 7/7 [==============================] - 0s 39ms/step

# %%
# Generate the confusion matrix
cm = confusion_matrix(y_test, y_pred)

# Plot the confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()

# %%
# Print accuracy, precision, recall, and F1-score
print("Classification Report:")
print(classification_report(y_test, y_pred))
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.53      1.00      0.69        87
#            1       1.00      0.30      0.46       110
#
#     accuracy                           0.61       197
#    macro avg       0.77      0.65      0.58       197
# weighted avg       0.79      0.61      0.56       197

# %%
print("Quantum Neural Network Accuracy:", accuracy*100)
# Out:
# Quantum Neural Network Accuracy: 60.913705583756354

# %%
from sklearn.metrics import precision_score, recall_score, f1_score

# Calculate precision, recall, and f1-score
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)

print(f'Accuracy: {accuracy:.4f}')
print(f'Precision: {precision:.4f}')
print(f'Recall: {recall:.4f}')
print(f'F1 Score: {f1:.4f}')
# Out:
# Accuracy: 0.6091
# Precision: 1.0000
# Recall: 0.3000
# F1 Score: 0.4615

# %%
# Get predicted probabilities for the positive class
y_pred_prob_qnn = quantum_model2.predict(X_test)  # This will return probabilities

# Compute ROC curve and AUC for ANN
fpr_qnn, tpr_qnn, _ = roc_curve(y_test, y_pred_prob_qnn)
auc_qnn = roc_auc_score(y_test, y_pred_prob_qnn)
print("QNN AUC:", auc_qnn)

# Plot ROC curve
plt.figure()
plt.plot(fpr_qnn, tpr_qnn, label='QNN ROC curve (AUC = {:.2f})'.format(auc_qnn))
plt.plot([0, 1], [0, 1], 'r--')  # Diagonal line
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve for QNN-Amplitude Embedding')
plt.legend(loc='lower right')
plt.show()
# Out:
# 7/7 [==============================] - 0s 60ms/step
# QNN AUC: 0.9218390804597701
